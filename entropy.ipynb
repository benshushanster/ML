# %% [markdown]
# Imports my file

# %%
from decision_tree_ex7 import entropy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Check the entropy function

# %%
x=np.linspace(0.0, 1.0, 100)
y=entropy(x)
plt.ylabel('entropy')
plt.xlabel('probability')
plt.plot(x,y)
